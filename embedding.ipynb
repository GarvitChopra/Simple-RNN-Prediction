# %%
## one hot encoding
from tensorflow.keras.preprocessing.text import one_hot
## Word Embedding
from tensorflow.keras.layers import Embedding 
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
# Out:
# WARNING:tensorflow:From c:\Users\dell\OneDrive\Desktop\GenAi\annclassification-project\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
## Sentences
sent = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good',
]

# %%
## Define the vocabulary size 
voc_size = 10000
## One hot Representation
one_hot_repr = [one_hot(words,voc_size) for words in sent]
one_hot_repr
# Out:
# [[1719, 4208, 9797, 6443],
#  [1719, 4208, 9797, 109],
#  [1719, 2850, 9797, 5452],
#  [4890, 4756, 1352, 7036, 4036],
#  [4890, 4756, 1352, 7036, 7060],
#  [9097, 1719, 7365, 9797, 3696],
#  [1758, 7432, 9273, 7036]]

# %%
import numpy as np

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 1719 4208 9797 6443]
#  [   0    0    0    0 1719 4208 9797  109]
#  [   0    0    0    0 1719 2850 9797 5452]
#  [   0    0    0 4890 4756 1352 7036 4036]
#  [   0    0    0 4890 4756 1352 7036 7060]
#  [   0    0    0 9097 1719 7365 9797 3696]
#  [   0    0    0    0 1758 7432 9273 7036]]

# %%
## feature Representation
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From c:\Users\dell\OneDrive\Desktop\GenAi\annclassification-project\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\dell\OneDrive\Desktop\GenAi\annclassification-project\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 203ms/step
# array([[[-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [ 0.03939578, -0.03064185,  0.02084306, -0.00922209,
#           0.00729082,  0.03545203, -0.03759144,  0.01264136,
#          -0.04247061, -0.01447247],
#         [ 0.0470233 ,  0.02133774, -0.01482365, -0.02917832,
#           0.02621381,  0.04946217, -0.03356781, -0.02023859,
#          -0.00790954,  0.02767881],
#         [ 0.02182169, -0.01345416,  0.04617867,  0.00623598,
#          -0.04328546, -0.02521032, -0.00615772,  0.03618386,
#          -0.04977812, -0.00838847],
#         [-0.02455552, -0.028362  ,  0.00157272,  0.02183218,
#          -0.02240069, -0.03216328,  0.00960884,  0.02654611,
#          -0.00916601,  0.03713467]],
#
#        [[-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [ 0.03939578, -0.03064185,  0.02084306, -0.00922209,
#           0.00729082,  0.03545203, -0.03759144,  0.01264136,
#          -0.04247061, -0.01447247],
#         [ 0.0470233 ,  0.02133774, -0.01482365, -0.02917832,
#           0.02621381,  0.04946217, -0.03356781, -0.02023859,
#          -0.00790954,  0.02767881],
#         [ 0.02182169, -0.01345416,  0.04617867,  0.00623598,
#          -0.04328546, -0.02521032, -0.00615772,  0.03618386,
#          -0.04977812, -0.00838847],
#         [ 0.01313767,  0.01583398, -0.00758189, -0.03170127,
#           0.04561119,  0.01242187, -0.0061602 , -0.03785157,
#          -0.01827816,  0.02371738]],
#
#        [[-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [ 0.03939578, -0.03064185,  0.02084306, -0.00922209,
#           0.00729082,  0.03545203, -0.03759144,  0.01264136,
#          -0.04247061, -0.01447247],
#         [-0.04653439, -0.01907065, -0.02973124, -0.03532257,
#           0.00678873, -0.0074123 , -0.02675568,  0.00341188,
#           0.00192002,  0.02315914],
#         [ 0.02182169, -0.01345416,  0.04617867,  0.00623598,
#          -0.04328546, -0.02521032, -0.00615772,  0.03618386,
#          -0.04977812, -0.00838847],
#         [ 0.00552768, -0.00013518, -0.02925085,  0.02230373,
#          -0.02978211, -0.03396423,  0.022682  , -0.03748707,
#          -0.02277997, -0.04886137]],
#
#        [[-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [ 0.0460217 ,  0.04692448,  0.00173289, -0.04619703,
#           0.04510793,  0.02655727,  0.02230677,  0.01000249,
#           0.03357561, -0.03161917],
#         [ 0.04880545, -0.00721819, -0.01515042, -0.00282139,
#          -0.03800268,  0.03743913,  0.03109362, -0.04458282,
#           0.03528318, -0.02463757],
#         [ 0.00196736,  0.02694863,  0.04468084, -0.01467816,
#           0.03044592,  0.0252662 , -0.03247843,  0.02116186,
#          -0.04561455, -0.03610862],
#         [ 0.00217959, -0.00980251, -0.04693786,  0.04767909,
#           0.02049763, -0.01963871,  0.01959534,  0.03927222,
#          -0.02896473, -0.01872617],
#         [ 0.03390192,  0.03081172, -0.02909281, -0.01263369,
#          -0.03712242, -0.044995  ,  0.04561101,  0.03908082,
#          -0.04087321,  0.04334891]],
#
#        [[-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [ 0.0460217 ,  0.04692448,  0.00173289, -0.04619703,
#           0.04510793,  0.02655727,  0.02230677,  0.01000249,
#           0.03357561, -0.03161917],
#         [ 0.04880545, -0.00721819, -0.01515042, -0.00282139,
#          -0.03800268,  0.03743913,  0.03109362, -0.04458282,
#           0.03528318, -0.02463757],
#         [ 0.00196736,  0.02694863,  0.04468084, -0.01467816,
#           0.03044592,  0.0252662 , -0.03247843,  0.02116186,
#          -0.04561455, -0.03610862],
#         [ 0.00217959, -0.00980251, -0.04693786,  0.04767909,
#           0.02049763, -0.01963871,  0.01959534,  0.03927222,
#          -0.02896473, -0.01872617],
#         [ 0.02195619, -0.0447688 , -0.01904184, -0.01432934,
#          -0.02675204,  0.01040709, -0.01822145,  0.03153403,
#           0.02274574, -0.04786498]],
#
#        [[-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.00487234, -0.04259511, -0.00019807, -0.0172546 ,
#          -0.0174172 ,  0.00750949, -0.02607385,  0.00652974,
#           0.01738722, -0.03683156],
#         [ 0.03939578, -0.03064185,  0.02084306, -0.00922209,
#           0.00729082,  0.03545203, -0.03759144,  0.01264136,
#          -0.04247061, -0.01447247],
#         [ 0.0314945 ,  0.02082559,  0.00089327,  0.01134868,
#          -0.03042558, -0.03286397,  0.01394897, -0.00206297,
#           0.04078785,  0.04090558],
#         [ 0.02182169, -0.01345416,  0.04617867,  0.00623598,
#          -0.04328546, -0.02521032, -0.00615772,  0.03618386,
#          -0.04977812, -0.00838847],
#         [-0.02642267,  0.04904607,  0.04861507,  0.00913184,
#           0.02232331, -0.04661192,  0.02569873,  0.0031641 ,
#          -0.0304742 , -0.03692725]],
#
#        [[-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [-0.02408331, -0.03686864,  0.02360172,  0.04839009,
#          -0.0160486 ,  0.03569441,  0.02590665, -0.02616881,
#           0.02503148, -0.038121  ],
#         [ 0.01175944, -0.04091526,  0.04156235,  0.02934405,
#          -0.04820402, -0.01228375, -0.04333948, -0.02695029,
#          -0.00652013,  0.03342697],
#         [ 0.04385172, -0.03810834,  0.02490245, -0.02004992,
#          -0.0043148 ,  0.00614173, -0.00441326,  0.01142695,
#          -0.02277154,  0.01633756],
#         [-0.02359056,  0.01859702, -0.04083668, -0.02631384,
#           0.03450519, -0.02061968,  0.02688349, -0.03441959,
#           0.04034736, -0.03285307],
#         [ 0.00217959, -0.00980251, -0.04693786,  0.04767909,
#           0.02049763, -0.01963871,  0.01959534,  0.03927222,
#          -0.02896473, -0.01872617]]], dtype=float32)
